# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ### Playlist Dynamics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import matplotlib.dates as mdates

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5000)
# %matplotlib inline

# %% [markdown]
# Settings for getting figures in high resolution

# %%
# sns.set(rc={"figure.dpi": 300, 'savefig.dpi': 300})
# sns.set_context('notebook')
# sns.set_style("ticks")

# %%
df=pd.read_pickle('./dataset_/dataset_cleaned_popularity.pkl')
df.drop(columns=['index', 'level_0'], inplace=True)  # Comes from pickeling the file
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#        country                                                uri  popularity  \
# 0       Global  https://open.spotify.com/track/6FyRXC8tJUh863J...    31833.95
# 1          USA  https://open.spotify.com/track/6FyRXC8tJUh863J...        8.00
# 2    Argentina  https://open.spotify.com/track/6FyRXC8tJUh863J...    76924.40
# 3      Belgium  https://open.spotify.com/track/6FyRXC8tJUh863J...      849.60
# 4  Switzerland  https://open.spotify.com/track/6FyRXC8tJUh863J...    20739.10
#
#         title        artist release_type          sub_genre  artist_followers  \
# 0  adan y eva  Paulo Londra       single  argentine hip hop        11427104.0
# 1  adan y eva  Paulo Londra       single  argentine hip hop        11427104.0
# 2  adan y eva  Paulo Londra       single  argentine hip hop        11427104.0
# 3  adan y eva  Paulo Londra       single  argentine hip hop        11427104.0
# 4  adan y eva  Paulo Londra       single  argentine hip hop        11427104.0
#
#   explicit       album release_date track_number tracks_in_album  \
# 0    False  Adan y Eva   2018-11-05            1               1
# 1    False  Adan y Eva   2018-11-05            1               1
# 2    False  Adan y Eva   2018-11-05            1               1
# 3    False  Adan y Eva   2018-11-05            1               1
# 4    False  Adan y Eva   2018-11-05            1               1
#
#    danceability  energy key  loudness mode  speechiness  acoustics  \
# 0         0.767   0.709   1     -4.47    1        0.336      0.323
# 1         0.767   0.709   1     -4.47    1        0.336      0.323
# 2         0.767   0.709   1     -4.47    1        0.336      0.323
# 3         0.767   0.709   1     -4.47    1        0.336      0.323
# 4         0.767   0.709   1     -4.47    1        0.336      0.323
#
#    instrumentalness  liveness  valence    tempo time_signature    genre  \
# 0               0.0    0.0676     0.72  171.993              4  hip hop
# 1               0.0    0.0676     0.72  171.993              4  hip hop
# 2               0.0    0.0676     0.72  171.993              4  hip hop
# 3               0.0    0.0676     0.72  171.993              4  hip hop
# 4               0.0    0.0676     0.72  171.993              4  hip hop
#
#    days_since_release released_after_2017  explicit_false  explicit_true  \
# 0               740.0                 1.0               1              0
# 1               740.0                 1.0               1              0
# 2               740.0                 1.0               1              0
# 3               740.0                 1.0               1              0
# 4               740.0                 1.0               1              0
#
#    popu_max  top10_dummy  top50_dummy                      cluster  \
# 0        10          1.0          1.0                       global
# 1       191          0.0          0.0  english speaking and nordic
# 2         1          1.0          1.0             spanish speaking
# 3       126          0.0          0.0  english speaking and nordic
# 4        21          0.0          1.0  english speaking and nordic
#
#    duration_min  release_year  release_month  release_day
# 0       4.31065          2018             11            5
# 1       4.31065          2018             11            5
# 2       4.31065          2018             11            5
# 3       4.31065          2018             11            5
# 4       4.31065          2018             11            5

# %% [markdown]
# Take a look into the global playlist and make sense of why we have so many songs in it. Assumption is that each playlist should only have 200 songs in it.

# %%
christmas_songs = df[((df['album'].str.contains('christ', case=False)) |
                      (df['title'].str.contains('christ', case=False))
                      ) &
                     (df['country'] == 'Global')
                     ].sort_values(by=['popularity'], ascending=False)['uri'][:5]

# %% [markdown]
# Check multiple songs based on the example of the song sleigh ride.

# %%
df[(df['country'] == 'Global') & (df['title'] == 'sleigh ride')]
# Out:
#       country                                                uri  popularity  \
# 15215  Global  https://open.spotify.com/track/4ukUoXLuFzMixyZ...      200.15
# 16619  Global  https://open.spotify.com/track/597IVBYr60vm0HK...      248.55
# 38848  Global  https://open.spotify.com/track/6XAdcAseYtijN0Q...       76.00
# 46766  Global  https://open.spotify.com/track/1ODZGydlown4Ves...     2169.35
# 49133  Global  https://open.spotify.com/track/5ymVfeMK8cDew5v...       76.00
# 76936  Global  https://open.spotify.com/track/5ASM6Qjiav2xPe7...     1368.15
#
#              title           artist release_type           sub_genre  \
# 15215  sleigh ride  Ella Fitzgerald        album     adult standards
# 16619  sleigh ride       Carpenters        album     adult standards
# 38848  sleigh ride    Johnny Mathis        album     adult standards
# 46766  sleigh ride     The Ronettes        album  brill building pop
# 49133  sleigh ride    Andy Williams        album     adult standards
# 76936  sleigh ride     The Ronettes  compilation  brill building pop
#
#        artist_followers explicit  \
# 15215         1766898.0    False
# 16619         1562181.0    False
# 38848          243064.0    False
# 46766          153854.0    False
# 49133          315467.0    False
# 76936          153854.0    False
#
#                                                    album release_date  \
# 15215  Ella Wishes You A Swinging Christmas (Expanded...   1960-01-01
# 16619               Christmas Portrait (Special Edition)         1978
# 38848                                    Merry Christmas   1958-10-06
# 46766                             NOW 100 Hits Christmas   2019-11-08
# 49133                                    Merry Christmas         1965
# 76936         A Christmas Gift For You From Phil Spector         1963
#
#       track_number tracks_in_album  danceability  energy key  loudness mode  \
# 15215            5              18         0.508   0.287   1   -12.472    1
# 16619            5              21         0.694   0.243  11   -15.632    1
# 38848            3              12         0.605   0.663   1    -8.949    1
# 46766            9             100         0.527   0.768   2    -7.557    1
# 49133            1              12         0.571   0.634   5    -9.155    0
# 76936            5              13         0.529   0.772   2    -7.013    1
#
#        speechiness  acoustics  instrumentalness  liveness  valence    tempo  \
# 15215       0.0523      0.764          0.000000    0.1530    0.644  154.759
# 16619       0.0723      0.871          0.000000    0.1650    0.578  100.774
# 38848       0.0274      0.699          0.000000    0.1210    0.893  103.180
# 46766       0.0304      0.457          0.000002    0.3040    0.799   91.750
# 49133       0.0537      0.724          0.000000    0.0864    0.805  109.575
# 76936       0.0287      0.403          0.000002    0.3160    0.853   91.751
#
#       time_signature genre  days_since_release released_after_2017  \
# 15215              4   pop             22224.0                 0.0
# 16619              4   pop             15115.0               False
# 38848              4   pop             22676.0                 0.0
# 46766              4   pop               372.0                 1.0
# 49133              4   pop             19863.0               False
# 76936              4   pop             20594.0               False
#
#        explicit_false  explicit_true  popu_max  top10_dummy  top50_dummy  \
# 15215               1              0        79          0.0          0.0
# 16619               1              0        90          0.0          0.0
# 38848               1              0       132          0.0          0.0
# 46766               1              0        23          0.0          1.0
# 49133               1              0       138          0.0          0.0
# 76936               1              0        20          0.0          1.0
#
#       cluster  duration_min  release_year  release_month  release_day
# 15215  global      2.933117          1960              1            1
# 16619  global      2.657333          1978              1            1
# 38848  global      2.978667          1958             10            6
# 46766  global      3.013883          2019             11            8
# 49133  global      2.140000          1965              1            1
# 76936  global      3.021117          1963              1            1

# %% [markdown]
# ### Dynamics of songs from full database

# %%
df_db = pd.read_pickle('.\dataset_\original_db.pkl')
df_db.head(10)
# Out:
#    Unnamed: 0 country       date  position  \
# 0           0  Global 2020-11-05       1.0
# 1           1  Global 2020-11-05       2.0
# 2           2  Global 2020-11-05       3.0
# 3           3  Global 2020-11-05       4.0
# 4           4  Global 2020-11-05       5.0
# 5           5  Global 2020-11-05       6.0
# 6           6  Global 2020-11-05       7.0
# 7           7  Global 2020-11-05       8.0
# 8           8  Global 2020-11-05       9.0
# 9           9  Global 2020-11-05      10.0
#
#                                                  uri  \
# 0  https://open.spotify.com/track/47EiUVwUp4C9fGc...
# 1  https://open.spotify.com/track/35mvY5S1H3J2QZy...
# 2  https://open.spotify.com/track/3tjFYV6RSFtuktY...
# 3  https://open.spotify.com/track/7hxHWCCAIIxFLCz...
# 4  https://open.spotify.com/track/4y4spB9m0Q6026K...
# 5  https://open.spotify.com/track/1tkg4EHVoqnhR6i...
# 6  https://open.spotify.com/track/0t1kP63rueHleOh...
# 7  https://open.spotify.com/track/1yoMvmasuxZfqHE...
# 8  https://open.spotify.com/track/6Im9k8u9iIzKMrm...
# 9  https://open.spotify.com/track/4Oun2ylbjFKMPTi...
#
#                                  track                    title  \
# 0      Dakiti , Bad Bunny, Jhay Cortez                   dakiti
# 1            positions , Ariana Grande                positions
# 2                     Mood  , 24kGoldn                     mood
# 3           Lemonade  , Internet Money                 lemonade
# 4              Lonely  , Justin Bieber                   lonely
# 5  What You Know Bout Love , Pop Smoke  what you know bout love
# 6                       Dynamite , BTS                 dynamite
# 7                       Hawái , Maluma                    hawái
# 8                34+35 , Ariana Grande                    34+35
# 9                       WAP  , Cardi B                      wap
#
#                    artist  position_7day_ave
# 0  Bad Bunny, Jhay Cortez                3.0
# 1           Ariana Grande                4.0
# 2                24kGoldn                5.0
# 3          Internet Money                6.0
# 4           Justin Bieber                7.0
# 5               Pop Smoke                8.0
# 6                     BTS                9.0
# 7                  Maluma               10.0
# 8           Ariana Grande               11.0
# 9                 Cardi B               12.0

# %%
df_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9807001 entries, 0 to 9807000
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   country     object
#  2   date        object
#  3   position    float64
#  4   uri         object
#  5   track       object
#  6   title       object
#  7   artist      object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 598.6+ MB

# %% [markdown]
# Now lets take a a look and compare the same top5 christas songs.

# %%
df_global_christmas = df_db[(df_db['country'] == 'Global') & (df_db['uri'].isin(list(christmas_songs)))]
df_germany_christmas = df_db[(df_db['country'] == 'Germany') & (df_db['uri'].isin(list(christmas_songs)))]
df_usa_christmas = df_db[(df_db['country'] == 'USA') & (df_db['uri'].isin(list(christmas_songs)))]
df_france_christmas = df_db[(df_db['country'] == 'France') & (df_db['uri'].isin(list(christmas_songs)))]

# Some christians inside the country
df_indonesia_christmas = df_db[(df_db['country'] == 'Indonesia') & (df_db['uri'].isin(list(christmas_songs)))]

# Celebrate Christas but still low numbers
df_mexico_christmas = df_db[(df_db['country'] == 'Mexico') & (df_db['uri'].isin(list(christmas_songs)))]
df_peru_christmas = df_db[(df_db['country'] == 'Peru') & (df_db['uri'].isin(list(christmas_songs)))]
df_brazil_christmas = df_db[(df_db['country'] == 'Brazil') & (df_db['uri'].isin(list(christmas_songs)))]

# No or Commercial celebration
df_taiwan_christmas = df_db[(df_db['country'] == 'Taiwan') & (df_db['uri'].isin(list(christmas_songs)))]
df_malaysia_christmas = df_db[(df_db['country'] == 'Malaysia') & (df_db['uri'].isin(list(christmas_songs)))]
df_turkey_christmas = df_db[(df_db['country'] == 'Turkey') & (df_db['uri'].isin(list(christmas_songs)))]

# %%
df_db['country'].unique()
# Out:
# array(['Global', 'USA', 'UK', 'Argentina', 'Austria', 'Australia',
#        'Belgium', 'Brazil', 'Canada', 'Switzerland', 'Chile', 'Colombia',
#        'Costa Rica', 'Germany', 'Denmark', 'Ecuador', 'Spain', 'Finland',
#        'France', 'Indonesia', 'Ireland', 'Italy', 'Mexico', 'Malaysia',
#        'Netherlands', 'Norway', 'New Zealand', 'Peru', 'Philippines',
#        'Poland', 'Portugal', 'Sweden', 'Singapore', 'Turkey', 'Taiwan',
#        nan], dtype=object)

# %%
# Check for other christmas songs not in english
df_db[(df_db['country'] == 'Ecuador') & (df_db['date'] > "2018-12-01") & (df_db['date'] < "2019-01-01")]
# Out:
#          Unnamed: 0  country       date  position  \
# 4338000     4338000  Ecuador 2018-12-31       1.0
# 4338001     4338001  Ecuador 2018-12-31       2.0
# 4338002     4338002  Ecuador 2018-12-31       3.0
# 4338003     4338003  Ecuador 2018-12-31       4.0
# 4338004     4338004  Ecuador 2018-12-31       5.0
# ...             ...      ...        ...       ...
# 4343995     4343995  Ecuador 2018-12-02     196.0
# 4343996     4343996  Ecuador 2018-12-02     197.0
# 4343997     4343997  Ecuador 2018-12-02     198.0
# 4343998     4343998  Ecuador 2018-12-02     199.0
# 4343999     4343999  Ecuador 2018-12-02     200.0
#
#                                                        uri  \
# 4338000  https://open.spotify.com/track/6FyRXC8tJUh863J...
# 4338001  https://open.spotify.com/track/5iwz1NiezX7WWjn...
# 4338002  https://open.spotify.com/track/0s5DNDV6LAKn2u2...
# 4338003  https://open.spotify.com/track/116H0KvKr2Zl4RP...
# 4338004  https://open.spotify.com/track/2cYnZNzFRFK0H7v...
# ...                                                    ...
# 4343995  https://open.spotify.com/track/6Bl4kGTCAo1U9po...
# 4343996  https://open.spotify.com/track/2XVilv6s9GETnw9...
# 4343997  https://open.spotify.com/track/0CXEPVeQDLgDBfv...
# 4343998  https://open.spotify.com/track/48svUiwMMYQRPye...
# 4343999  https://open.spotify.com/track/71GAvRsilpo9pqd...
#
#                                                      track  \
# 4338000                          Adan y Eva , Paulo Londra
# 4338001                Calma - Remix , Pedro Capó, Farruko
# 4338002  Desconocidos , Mau y Ricky, Manuel Turizo, Camilo
# 4338003                                   MIA  , Bad Bunny
# 4338004  Ella Quiere Beber - Remix , Anuel AA, Romeo Sa...
# ...                                                    ...
# 4343995                    Ta to Gucci , Cauty, Rafa Pabön
# 4343996                               El Préstamo , Maluma
# 4343997                     Como Mirarte , Sebastian Yatra
# 4343998                          Tabaco Y Chanel , Bacilos
# 4343999                                      Mamita , CNCO
#
#                              title                              artist  \
# 4338000                 adan y eva                        Paulo Londra
# 4338001              calma - remix                 Pedro Capó, Farruko
# 4338002               desconocidos  Mau y Ricky, Manuel Turizo, Camilo
# 4338003                        mia                           Bad Bunny
# 4338004  ella quiere beber - remix              Anuel AA, Romeo Santos
# ...                            ...                                 ...
# 4343995                ta to gucci                   Cauty, Rafa Pabön
# 4343996                el préstamo                              Maluma
# 4343997               como mirarte                     Sebastian Yatra
# 4343998            tabaco y chanel                             Bacilos
# 4343999                     mamita                                CNCO
#
#          position_7day_ave
# 4338000           3.000000
# 4338001           4.000000
# 4338002           5.000000
# 4338003           6.000000
# 4338004           7.000000
# ...                    ...
# 4343995         198.000000
# 4343996         199.000000
# 4343997         133.333333
# 4343998          67.666667
# 4343999           2.000000
#
# [6000 rows x 9 columns]

# %%
df_france_christmas = df_db[(df_db['country'] == 'Ecuador') & (
    df_db['uri'].isin(list(christmas_songs)))]

plt.figure(figsize=(12, 8))
ax = sns.scatterplot(x='date', y='position',
                     data=df_france_christmas, hue='title')
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
ax.invert_yaxis()
ax.set_yticklabels(['', '1', '25', '50', '75', '100',
                   '125', '150', '175', '200'])
ax.set(title='Global Ranking Positions of top5 Christmas Songs')
ax.set(xlim=('2017-01', '2020-07'))
# Out:
# [(array(17167.), array(18444.))]

# %%
f, ax = plt.subplots(2, 2, figsize=(18, 14), sharex=True, sharey=True)

sns.scatterplot(x='date', y='position', data=df_global_christmas,
                hue='title', ax=ax[0, 0])
ax[0, 0].invert_yaxis()
ax[0, 0].set_yticklabels(['', '1', '25', '50', '75', '100', '125', '150', '175', '200'])
ax[0, 0].set_title('Global Playlist')
ax[0, 0].set(xlim=('2017-01', '2020-07'))

sns.scatterplot(x='date', y='position', data=df_germany_christmas, 
                hue='title', ax=ax[1, 0])
ax[1, 0].set_yticklabels(['', '1', '25', '50', '75', '100',
                  '125', '150', '175', '200'])
ax[1, 0].set_title('Germany  Playlist')
ax[1, 0].set(xlim=('2017-01', '2020-07'))

sns.scatterplot(x='date', y='position', data=df_usa_christmas,
                hue='title', ax=ax[1, 1])
ax[1, 1].set_yticklabels(['', '1', '25', '50', '75', '100',
                          '125', '150', '175', '200'])
ax[1, 1].set_title('USA Playlist')
ax[1, 1].set(xlim=('2017-01', '2020-07'))

sns.scatterplot(x='date', y='position', data=df_france_christmas,
                hue='title', ax=ax[0, 1])
ax[0, 1].legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
ax[0, 1].set_yticklabels(['', '1', '25', '50', '75', '100',
                          '125', '150', '175', '200'])
ax[0, 1].set_title('France Playlist')
ax[0, 1].set(xlim=('2017-01', '2020-07'))

ax[0, 0].get_legend().remove()
ax[1, 0].get_legend().remove()
ax[1, 1].get_legend().remove()
f.suptitle('Ranking Positions of top5 most popular christmas songs')
f.tight_layout()
f.subplots_adjust(top=0.90)

# %%
f, ax = plt.subplots(2, 2, figsize=(18, 14), sharex=True, sharey=True)

sns.scatterplot(x='date', y='position', data=df_global_christmas,
                hue='title', ax=ax[0, 0])
ax[0, 0].invert_yaxis()
ax[0, 0].set_yticklabels(['', '1', '25', '50', '75', '100', '125', '150', '175', '200'])
ax[0, 0].set_title('Global Playlist')
ax[0, 0].set(xlim=('2017-01', '2020-07'))

sns.scatterplot(x='date', y='position', data=df_germany_christmas, 
                hue='title', ax=ax[1, 0])
ax[1, 0].set_yticklabels(['', '1', '25', '50', '75', '100',
                  '125', '150', '175', '200'])
ax[1, 0].set_title('Germany  Playlist')
ax[1, 0].set(xlim=('2017-01', '2020-07'))

sns.scatterplot(x='date', y='position', data=df_usa_christmas,
                hue='title', ax=ax[1, 1])
ax[1, 1].set_yticklabels(['', '1', '25', '50', '75', '100',
                          '125', '150', '175', '200'])
ax[1, 1].set_title('USA Playlist')
ax[1, 1].set(xlim=('2017-01', '2020-07'))

sns.scatterplot(x='date', y='position', data=df_taiwan_christmas,
                hue='title', ax=ax[0, 1])
ax[0, 1].legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
ax[0, 1].set_yticklabels(['', '1', '25', '50', '75', '100',
                          '125', '150', '175', '200'])
ax[0, 1].set_title('Taiwan Playlist')
ax[0, 1].set(xlim=('2017-01', '2020-07'))

ax[0, 0].get_legend().remove()
ax[1, 0].get_legend().remove()
ax[1, 1].get_legend().remove()
f.suptitle('Ranking Positions of top5 most popular christmas songs')
f.tight_layout()
f.subplots_adjust(top=0.90)

# %%
df_db.to_pickle('dataset_\original_db.pkl')

# %% [markdown]
# Futher work: - Analzye seasonal patterns: Christmas songs or others

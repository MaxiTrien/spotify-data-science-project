# %% [markdown]
# **Getting the data**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %%
spotify_songs_df=pd.read_csv('dataset_\spotify_songs.csv')

# %%
spotify_songs_df.head(20)
# Out:
#                   track_id                                         track_name  \
# 0   6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1   0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2   1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3   75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4   1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
# 5   7fvUMiyapMsRRxr07cU8Ef  Beautiful People (feat. Khalid) - Jack Wins Remix
# 6   2OAylPUDDfwRGfe0lYqlCQ                    Never Really Over - R3HAB Remix
# 7   6b1RNvAcJjQH73eZO4BLAB           Post Malone (feat. RANI) - GATTÜSO Remix
# 8   7bF6tCO3gFb8INrEDcjNT5             Tough Love - Tiësto Remix / Radio Edit
# 9   1IXGILkPm0tOCNeq00kCPa                If I Can't Have You - Gryffin Remix
# 10  3eFJI470ALf1EYjywPRsJy  Cross Me (feat. Chance the Rapper & PnB Rock) ...
# 11  3iJeF2izF1QcpCgUc97BLl                              Hate Me - R3HAB Remix
# 12  6e0CvGZf7CouOpYF8toXHC                                         Body On My
# 13  3eLdNmnRWr9gIyBcqTSSti     SOS - Laidback Luke Tribute Remix / Radio Edit
# 14  55nMnifaQWKe3f9cbwOXwx  Summer Days (feat. Macklemore & Patrick Stump ...
# 15  1EJgymgJHcjSOGSHcYaxvW  South of the Border (feat. Camila Cabello & Ca...
# 16  5WaXMQMlQpq8pwIdaFP43L                 All My Friends - Eden Prince Remix
# 17  3TjLsDgL0bTbSQIF6M5Ki8  Say My Name (feat. Bebe Rexha & J Balvin) - Lu...
# 18  0GfS3y8Jd7SHWd9R51s7Fo  Dancing With A Stranger (With Normani) - Cheat...
# 19  2v3DuCVBbopteJqdM7aKQK                         Let It Be Me - Sondr Remix
#
#         track_artist  track_popularity          track_album_id  \
# 0         Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1           Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2       Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3   The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4      Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
# 5         Ed Sheeran                67  2yiy9cd2QktrNvWC2EUi0k
# 6         Katy Perry                62  7INHYSeusaFlyrHSNxm8qH
# 7          Sam Feldt                69  6703SRPsLkS4bPtMFFJes1
# 8             Avicii                68  7CvAfGvq4RlIwEbT9o8Iav
# 9       Shawn Mendes                67  4QxzbfSsVryEQwvPFEV5Iu
# 10        Ed Sheeran                58  49bXZtlI5kQSqQMSCnSaWO
# 11    Ellie Goulding                67  6e6RVFWdZaoTiLAZOCMnps
# 12       Loud Luxury                67  2R66I0nzp3NnuUlzIGWQ5P
# 13            Avicii                68  7Al4TIo0c5twNLfdOh1y1u
# 14     Martin Garrix                63  2vx3BtBMn8Ed3ygEg1OT2t
# 15        Ed Sheeran                66  1imXAvLuowvPYIsFMYUPY0
# 16       AJ Mitchell                60  4lXBBbiEgwTzcfAkqdXJV1
# 17      David Guetta                65  19z3vpbBT09lZ54neDfuFL
# 18         Sam Smith                69  2LDzwN4iZ4qbSA32E9CG4Q
# 19        Steve Aoki                35  097kyycr5ZuLS2cPwwUHwt
#
#                                      track_album_name  \
# 0   I Don't Care (with Justin Bieber) [Loud Luxury...
# 1                     Memories (Dillon Francis Remix)
# 2                     All the Time (Don Diablo Remix)
# 3                         Call You Mine - The Remixes
# 4             Someone You Loved (Future Humans Remix)
# 5   Beautiful People (feat. Khalid) [Jack Wins Remix]
# 6                     Never Really Over (R3HAB Remix)
# 7            Post Malone (feat. RANI) [GATTÜSO Remix]
# 8                           Tough Love (Tiësto Remix)
# 9                 If I Can't Have You (Gryffin Remix)
# 10  Cross Me (feat. Chance the Rapper & PnB Rock) ...
# 11                              Hate Me (R3HAB Remix)
# 12                                         Body On My
# 13                  SOS (Laidback Luke Tribute Remix)
# 14  Summer Days (feat. Macklemore & Patrick Stump ...
# 15  South of the Border (feat. Camila Cabello & Ca...
# 16                 All My Friends (Eden Prince Remix)
# 17  Say My Name (feat. Bebe Rexha & J Balvin) [Luc...
# 18  Dancing With A Stranger (With Normani) [Cheat ...
# 19                             Let It Be Me (Remixes)
#
#    track_album_release_date playlist_name             playlist_id  \
# 0                2019-06-14     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 1                2019-12-13     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 2                2019-07-05     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 3                2019-07-19     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 4                2019-03-05     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 5                2019-07-11     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 6                2019-07-26     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 7                2019-08-29     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 8                2019-06-14     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 9                2019-06-20     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 10               2019-06-21     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 11               2019-08-16     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 12               2019-03-29     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 13               2019-05-17     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 14               2019-07-12     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 15               2019-12-11     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 16               2019-05-03     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 17               2018-12-28     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 18               2019-03-08     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 19               2019-10-18     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
#
#    playlist_genre playlist_subgenre  danceability  energy  key  loudness  \
# 0             pop         dance pop         0.748   0.916    6    -2.634
# 1             pop         dance pop         0.726   0.815   11    -4.969
# 2             pop         dance pop         0.675   0.931    1    -3.432
# 3             pop         dance pop         0.718   0.930    7    -3.778
# 4             pop         dance pop         0.650   0.833    1    -4.672
# 5             pop         dance pop         0.675   0.919    8    -5.385
# 6             pop         dance pop         0.449   0.856    5    -4.788
# 7             pop         dance pop         0.542   0.903    4    -2.419
# 8             pop         dance pop         0.594   0.935    8    -3.562
# 9             pop         dance pop         0.642   0.818    2    -4.552
# 10            pop         dance pop         0.679   0.923    6    -6.500
# 11            pop         dance pop         0.437   0.774    8    -4.918
# 12            pop         dance pop         0.744   0.726    1    -4.675
# 13            pop         dance pop         0.572   0.915    5    -4.451
# 14            pop         dance pop         0.690   0.780    5    -4.446
# 15            pop         dance pop         0.805   0.835    0    -4.603
# 16            pop         dance pop         0.694   0.901    1    -4.322
# 17            pop         dance pop         0.678   0.747   10    -5.289
# 18            pop         dance pop         0.746   0.557    1    -6.722
# 19            pop         dance pop         0.467   0.821    7    -5.466
#
#     mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0      1       0.0583       0.10200          0.000000    0.0653    0.518
# 1      1       0.0373       0.07240          0.004210    0.3570    0.693
# 2      0       0.0742       0.07940          0.000023    0.1100    0.613
# 3      1       0.1020       0.02870          0.000009    0.2040    0.277
# 4      1       0.0359       0.08030          0.000000    0.0833    0.725
# 5      1       0.1270       0.07990          0.000000    0.1430    0.585
# 6      0       0.0623       0.18700          0.000000    0.1760    0.152
# 7      0       0.0434       0.03350          0.000005    0.1110    0.367
# 8      1       0.0565       0.02490          0.000004    0.6370    0.366
# 9      1       0.0320       0.05670          0.000000    0.0919    0.590
# 10     1       0.1810       0.14600          0.000005    0.1240    0.752
# 11     1       0.0554       0.14800          0.000000    0.1330    0.329
# 12     1       0.0463       0.03990          0.000000    0.3740    0.687
# 13     0       0.0625       0.01110          0.000000    0.3390    0.678
# 14     0       0.0594       0.00733          0.001830    0.0729    0.238
# 15     1       0.0896       0.13000          0.000005    0.3650    0.722
# 16     0       0.0948       0.07020          0.000000    0.4270    0.368
# 17     0       0.1650       0.03950          0.000000    0.1740    0.516
# 18     1       0.0542       0.10300          0.003600    0.1380    0.324
# 19     1       0.0934       0.00791          0.000441    0.1310    0.232
#
#       tempo  duration_ms
# 0   122.036       194754
# 1    99.972       162600
# 2   124.008       176616
# 3   121.956       169093
# 4   123.976       189052
# 5   124.982       163049
# 6   112.648       187675
# 7   127.936       207619
# 8   127.015       193187
# 9   124.957       253040
# 10  121.984       207894
# 11  123.125       203733
# 12  121.985       192507
# 13  123.919       164516
# 14  126.070       255238
# 15  125.028       188230
# 16  118.051       173548
# 17  120.002       189375
# 18  111.961       159404
# 19  122.676       185366

# %%
print('Dataset: ', spotify_songs_df.shape[0], 'Rows with', spotify_songs_df.shape[1], 'Features')
# Out:
# Dataset:  32833 Rows with 23 Features

# %% [markdown]
# **Exploratory data analysis**

# %%
spotify_songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
# dtypes: float64(9), int64(4), object(10)
# memory usage: 5.8+ MB

# %%
spotify_songs_df.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'duration_s', 'duration_min'],
#       dtype='object')

# %%
# Pick numerical features
df_numeric = spotify_songs_df[['track_popularity', 'danceability', 'energy', 'loudness', 'speechiness',
                               'acousticness', 'instrumentalness', 'liveness',
                               'valence', 'tempo','duration_min']]
df_numeric.head(5)
# Out:
#    track_popularity  danceability  energy  loudness  speechiness  \
# 0                66         0.748   0.916    -2.634       0.0583
# 1                67         0.726   0.815    -4.969       0.0373
# 2                70         0.675   0.931    -3.432       0.0742
# 3                60         0.718   0.930    -3.778       0.1020
# 4                69         0.650   0.833    -4.672       0.0359
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_min
# 0        0.1020          0.000000    0.0653    0.518  122.036      3.245900
# 1        0.0724          0.004210    0.3570    0.693   99.972      2.710000
# 2        0.0794          0.000023    0.1100    0.613  124.008      2.943600
# 3        0.0287          0.000009    0.2040    0.277  121.956      2.818217
# 4        0.0803          0.000000    0.0833    0.725  123.976      3.150867

# %%
df_numeric.describe()
# Out:
#        track_popularity  danceability        energy      loudness  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean          42.477081      0.654850      0.698619     -6.719499
# std           24.984074      0.145085      0.180910      2.988436
# min            0.000000      0.000000      0.000175    -46.448000
# 25%           24.000000      0.563000      0.581000     -8.171000
# 50%           45.000000      0.672000      0.721000     -6.166000
# 75%           62.000000      0.761000      0.840000     -4.645000
# max          100.000000      0.983000      1.000000      1.275000
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  32833.000000  32833.000000      32833.000000  32833.000000
# mean       0.107068      0.175334          0.084747      0.190176
# std        0.101314      0.219633          0.224230      0.154317
# min        0.000000      0.000000          0.000000      0.000000
# 25%        0.041000      0.015100          0.000000      0.092700
# 50%        0.062500      0.080400          0.000016      0.127000
# 75%        0.132000      0.255000          0.004830      0.248000
# max        0.918000      0.994000          0.994000      0.996000
#
#             valence         tempo  duration_min
# count  32833.000000  32833.000000  32833.000000
# mean       0.510561    120.881132      3.763330
# std        0.233146     26.903624      0.997233
# min        0.000000      0.000000      0.066667
# 25%        0.331000     99.960000      3.130317
# 50%        0.512000    121.984000      3.600000
# 75%        0.693000    133.918000      4.226417
# max        0.991000    239.440000      8.630167

# %%
#Finding missing values on the dataset
spotify_songs_df.isnull().sum()
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
#Listing the entries with missing values
spotify_songs_df[pd.isnull(spotify_songs_df["track_artist"])].transpose()
# Out:
#                                            8151                    9282   \
# track_id                  69gRFGOWY9OMpFJgFol1u0  5cjecvX0CmC9gK0Laf5EMQ
# track_name                                   NaN                     NaN
# track_artist                                 NaN                     NaN
# track_popularity                               0                       0
# track_album_id            717UG2du6utFe7CdmpuUe3  3luHJEPw434tvNbme3SP8M
# track_album_name                             NaN                     NaN
# track_album_release_date              2012-01-05              2017-12-01
# playlist_name                            HIP&HOP             GANGSTA Rap
# playlist_id               5DyJsJZOpMJh34WvUrQzMV  5GA8GDo7RQC3JEanT81B3g
# playlist_genre                               rap                     rap
# playlist_subgenre               southern hip hop            gangster rap
# danceability                               0.714                   0.678
# energy                                     0.821                   0.659
# key                                            6                      11
# loudness                                  -7.635                  -5.364
# mode                                           1                       0
# speechiness                                0.176                   0.319
# acousticness                               0.041                  0.0534
# instrumentalness                             0.0                     0.0
# liveness                                   0.116                   0.553
# valence                                    0.649                   0.191
# tempo                                     95.999                 146.153
# duration_ms                               282707                  202235
#
#                                            9283                    19568  \
# track_id                  5TTzhRSWQS4Yu8xTgAuq6D  3VKFip3OdAvv4OfNTgFWeQ
# track_name                                   NaN                     NaN
# track_artist                                 NaN                     NaN
# track_popularity                               0                       0
# track_album_id            3luHJEPw434tvNbme3SP8M  717UG2du6utFe7CdmpuUe3
# track_album_name                             NaN                     NaN
# track_album_release_date              2017-12-01              2012-01-05
# playlist_name                        GANGSTA Rap      Reggaeton viejito🔥
# playlist_id               5GA8GDo7RQC3JEanT81B3g  0si5tw70PIgPkY1Eva6V8f
# playlist_genre                               rap                   latin
# playlist_subgenre                   gangster rap               reggaeton
# danceability                               0.465                   0.675
# energy                                      0.82                   0.919
# key                                           10                      11
# loudness                                  -5.907                  -6.075
# mode                                           0                       0
# speechiness                                0.307                  0.0366
# acousticness                              0.0963                  0.0606
# instrumentalness                             0.0                 0.00653
# liveness                                  0.0888                   0.103
# valence                                    0.505                   0.726
# tempo                                     86.839                  97.017
# duration_ms                               206465                  252773
#
#                                            19811
# track_id                  69gRFGOWY9OMpFJgFol1u0
# track_name                                   NaN
# track_artist                                 NaN
# track_popularity                               0
# track_album_id            717UG2du6utFe7CdmpuUe3
# track_album_name                             NaN
# track_album_release_date              2012-01-05
# playlist_name                      latin hip hop
# playlist_id               3nH8aytdqNeRbcRCg3dw9q
# playlist_genre                             latin
# playlist_subgenre                  latin hip hop
# danceability                               0.714
# energy                                     0.821
# key                                            6
# loudness                                  -7.635
# mode                                           1
# speechiness                                0.176
# acousticness                               0.041
# instrumentalness                             0.0
# liveness                                   0.116
# valence                                    0.649
# tempo                                     95.999
# duration_ms                               282707

# %%
#Finding number of duplicated values on the dataset
spotify_songs_df.duplicated().sum()
# Out:
# 0

# %%
#Viewing the most popular songs revealed that there were actually duplicates
spotify_songs_df.sort_values('track_popularity',ascending=False).head()
# Out:
#                      track_id    track_name    track_artist  track_popularity  \
# 20091  2XU0oxnq2qxCpomAAuJY8K  Dance Monkey     Tones and I               100
# 1551   2XU0oxnq2qxCpomAAuJY8K  Dance Monkey     Tones and I               100
# 30202  696DnlkuDOXcMAnKlTgXXK       ROXANNE  Arizona Zervas                99
# 23104  696DnlkuDOXcMAnKlTgXXK       ROXANNE  Arizona Zervas                99
# 21468  696DnlkuDOXcMAnKlTgXXK       ROXANNE  Arizona Zervas                99
#
#                track_album_id                             track_album_name  \
# 20091  0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
# 1551   0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
# 30202  6HJDrXs0hpebaRFKA1sF90                                      ROXANNE
# 23104  6HJDrXs0hpebaRFKA1sF90                                      ROXANNE
# 21468  6HJDrXs0hpebaRFKA1sF90                                      ROXANNE
#
#       track_album_release_date  \
# 20091               2019-10-17
# 1551                2019-10-17
# 30202               2019-10-10
# 23104               2019-10-10
# 21468               2019-10-10
#
#                                            playlist_name  \
# 20091                          Global Top 50 | 2020 Hits
# 1551   post-teen alternative, indie, pop (large variety)
# 30202  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23104  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 21468                                 Contemporary Urban
#
#                   playlist_id playlist_genre   playlist_subgenre  \
# 20091  1KNl4AYfgZtOVm9KHkhPTF          latin       latin hip hop
# 1551   1y42gwI5cuwjBslPyQNfqb            pop       post-teen pop
# 30202  3xMQTDLOIGvj3lWH5e5x6F            edm             pop edm
# 23104  3xMQTDLOIGvj3lWH5e5x6F            r&b             hip pop
# 21468  6wyJ4bsjZaUKa9f6GeZlAO            r&b  urban contemporary
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 20091         0.824   0.588    6    -6.400     0       0.0924        0.6920
# 1551          0.824   0.588    6    -6.400     0       0.0924        0.6920
# 30202         0.621   0.601    6    -5.616     0       0.1480        0.0522
# 23104         0.621   0.601    6    -5.616     0       0.1480        0.0522
# 21468         0.621   0.601    6    -5.616     0       0.1480        0.0522
#
#        instrumentalness  liveness  valence    tempo  duration_ms
# 20091          0.000104     0.149    0.513   98.027       209438
# 1551           0.000104     0.149    0.513   98.027       209438
# 30202          0.000000     0.460    0.457  116.735       163636
# 23104          0.000000     0.460    0.457  116.735       163636
# 21468          0.000000     0.460    0.457  116.735       163636

# %%
#Those duplicates don't necessarily have the same numeric values and may be from differen't albums
spotify_songs_df[spotify_songs_df['track_name']=='Dance Monkey']
# Out:
#                      track_id    track_name track_artist  track_popularity  \
# 623    3g1MMelMBxLjtKwcIVFe0N  Dance Monkey      Skylike                63
# 922    5ZULALImTm80tzUbYQYM9d  Dance Monkey  Tones and I                92
# 1298   1rgnBhdG2JDFTbYkYRZAku  Dance Monkey  Tones and I                79
# 1349   421leiR6jKlH5KDdwLYrOs  Dance Monkey  Tones and I                43
# 1551   2XU0oxnq2qxCpomAAuJY8K  Dance Monkey  Tones and I               100
# 4699   421leiR6jKlH5KDdwLYrOs  Dance Monkey  Tones and I                43
# 10348  1LCG7BBh96DUUV6MuQhFad  Dance Monkey       Coopex                57
# 17088  0y3elN0Dm4b0bYQEQgTatE  Dance Monkey  Yann Muller                53
# 18312  5ZULALImTm80tzUbYQYM9d  Dance Monkey  Tones and I                92
# 19262  421leiR6jKlH5KDdwLYrOs  Dance Monkey  Tones and I                43
# 19720  5ZULALImTm80tzUbYQYM9d  Dance Monkey  Tones and I                92
# 20091  2XU0oxnq2qxCpomAAuJY8K  Dance Monkey  Tones and I               100
# 23099  1rgnBhdG2JDFTbYkYRZAku  Dance Monkey  Tones and I                79
# 23120  1LCG7BBh96DUUV6MuQhFad  Dance Monkey       Coopex                57
# 23757  5ZULALImTm80tzUbYQYM9d  Dance Monkey  Tones and I                92
# 27752  3g1MMelMBxLjtKwcIVFe0N  Dance Monkey      Skylike                63
# 30196  1rgnBhdG2JDFTbYkYRZAku  Dance Monkey  Tones and I                79
# 30222  1LCG7BBh96DUUV6MuQhFad  Dance Monkey       Coopex                57
#
#                track_album_id                             track_album_name  \
# 623    2iU9q30hhHCSN6Anlj3E5K                                 Dance Monkey
# 922    2pJXQvY0YeDvVJ9gMU9G7j                          The Kids Are Coming
# 1298   31IDBea3eEs57a0joX6TjN                                 Dance Monkey
# 1349   5i6CS5XcLZGLgaNCKlJvc2                                 Dance Monkey
# 1551   0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
# 4699   5i6CS5XcLZGLgaNCKlJvc2                                 Dance Monkey
# 10348  4bMaWB6yZh1ulaxHqRKh6Q                                 Dance Monkey
# 17088  2aG4dcRRkElx1GhVq0Tfvb                                 Dance Monkey
# 18312  2pJXQvY0YeDvVJ9gMU9G7j                          The Kids Are Coming
# 19262  5i6CS5XcLZGLgaNCKlJvc2                                 Dance Monkey
# 19720  2pJXQvY0YeDvVJ9gMU9G7j                          The Kids Are Coming
# 20091  0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
# 23099  31IDBea3eEs57a0joX6TjN                                 Dance Monkey
# 23120  4bMaWB6yZh1ulaxHqRKh6Q                                 Dance Monkey
# 23757  2pJXQvY0YeDvVJ9gMU9G7j                          The Kids Are Coming
# 27752  2iU9q30hhHCSN6Anlj3E5K                                 Dance Monkey
# 30196  31IDBea3eEs57a0joX6TjN                                 Dance Monkey
# 30222  4bMaWB6yZh1ulaxHqRKh6Q                                 Dance Monkey
#
#       track_album_release_date  \
# 623                 2019-09-06
# 922                 2019-08-29
# 1298                2019-05-10
# 1349                2019-05-10
# 1551                2019-10-17
# 4699                2019-05-10
# 10348               2019-12-23
# 17088               2019-12-20
# 18312               2019-08-29
# 19262               2019-05-10
# 19720               2019-08-29
# 20091               2019-10-17
# 23099               2019-05-10
# 23120               2019-12-23
# 23757               2019-08-29
# 27752               2019-09-06
# 30196               2019-05-10
# 30222               2019-12-23
#
#                                            playlist_name  \
# 623                                          Pop / Dance
# 922                                       Pop Dance Hits
# 1298     Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# 1349     Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# 1551   post-teen alternative, indie, pop (large variety)
# 4699                                   indie poptimism🕺🏻
# 10348                                        Trap Nation
# 17088  Tropical House Remixes 🍍 Tropical Remixes & Tr...
# 18312     2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥
# 19262                                     Verano Forever
# 19720     2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥
# 20091                          Global Top 50 | 2020 Hits
# 23099  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23120  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23757     2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥
# 27752                                   Crossfit‏‏​​   ‍
# 30196  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30222  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
#
#                   playlist_id playlist_genre playlist_subgenre  danceability  \
# 623    6mXh8CUBMBsBUu88a4eAQV            pop         dance pop         0.781
# 922    7eERKCkgNKCCx5GYdeMIZf            pop         dance pop         0.824
# 1298   46Cl6dmeiylK6TRGXr7hHe            pop     post-teen pop         0.825
# 1349   46Cl6dmeiylK6TRGXr7hHe            pop     post-teen pop         0.824
# 1551   1y42gwI5cuwjBslPyQNfqb            pop     post-teen pop         0.824
# 4699   6MQeEHHDs6HQkN5Dlj3oKo            pop   indie poptimism         0.824
# 10348  0NCspsyf0OS4BsPgGhkQXM            rap              trap         0.566
# 17088  3YdAwfgQLMS4AN2WjRfRlb          latin          tropical         0.830
# 18312  4JkkvMpVl4lSioqQjeAL0q          latin         latin pop         0.824
# 19262  37i9dQZF1DXdnGF35OawbN          latin         reggaeton         0.824
# 19720  4JkkvMpVl4lSioqQjeAL0q          latin     latin hip hop         0.824
# 20091  1KNl4AYfgZtOVm9KHkhPTF          latin     latin hip hop         0.824
# 23099  3xMQTDLOIGvj3lWH5e5x6F            r&b           hip pop         0.825
# 23120  3xMQTDLOIGvj3lWH5e5x6F            r&b           hip pop         0.566
# 23757  4JkkvMpVl4lSioqQjeAL0q            r&b           hip pop         0.824
# 27752  5GiPRvTccToqwOzkoAcDrY            edm     electro house         0.781
# 30196  3xMQTDLOIGvj3lWH5e5x6F            edm           pop edm         0.825
# 30222  3xMQTDLOIGvj3lWH5e5x6F            edm           pop edm         0.566
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 623     0.855    8    -4.853     0       0.2320         0.327
# 922     0.588    6    -6.400     0       0.0924         0.692
# 1298    0.593    6    -6.401     0       0.0988         0.688
# 1349    0.592    6    -6.400     0       0.0969         0.693
# 1551    0.588    6    -6.400     0       0.0924         0.692
# 4699    0.592    6    -6.400     0       0.0969         0.693
# 10348   0.767    6    -6.150     0       0.0817         0.106
# 17088   0.783    6    -5.202     0       0.0981         0.267
# 18312   0.588    6    -6.400     0       0.0924         0.692
# 19262   0.592    6    -6.400     0       0.0969         0.693
# 19720   0.588    6    -6.400     0       0.0924         0.692
# 20091   0.588    6    -6.400     0       0.0924         0.692
# 23099   0.593    6    -6.401     0       0.0988         0.688
# 23120   0.767    6    -6.150     0       0.0817         0.106
# 23757   0.588    6    -6.400     0       0.0924         0.692
# 27752   0.855    8    -4.853     0       0.2320         0.327
# 30196   0.593    6    -6.401     0       0.0988         0.688
# 30222   0.767    6    -6.150     0       0.0817         0.106
#
#        instrumentalness  liveness  valence    tempo  duration_ms
# 623            0.000248    0.2470    0.311  118.112       192203
# 922            0.000104    0.1490    0.513   98.027       209438
# 1298           0.000161    0.1700    0.540   98.078       209755
# 1349           0.000158    0.1780    0.540   98.074       209755
# 1551           0.000104    0.1490    0.513   98.027       209438
# 4699           0.000158    0.1780    0.540   98.074       209755
# 10348          0.000000    0.0862    0.236   98.111       194707
# 17088          0.001110    0.0818    0.649  105.072       161346
# 18312          0.000104    0.1490    0.513   98.027       209438
# 19262          0.000158    0.1780    0.540   98.074       209755
# 19720          0.000104    0.1490    0.513   98.027       209438
# 20091          0.000104    0.1490    0.513   98.027       209438
# 23099          0.000161    0.1700    0.540   98.078       209755
# 23120          0.000000    0.0862    0.236   98.111       194707
# 23757          0.000104    0.1490    0.513   98.027       209438
# 27752          0.000248    0.2470    0.311  118.112       192203
# 30196          0.000161    0.1700    0.540   98.078       209755
# 30222          0.000000    0.0862    0.236   98.111       194707

# %% [markdown]
# **Adding Columns**

# %%
spotify_songs_df['duration_s'] = spotify_songs_df['duration_ms']/1000
spotify_songs_df['duration_min'] = spotify_songs_df['duration_s']/60

# %% [markdown]
# **Visualizing of numerical columns**

# %%
palette = sns.color_palette("Set2")
sns.set_palette(palette)
sns.set_style('white')

# %%
spotify_songs_df.hist(figsize = (15,15))
plt.show()

# %% [markdown]
# **Visualizing of categorical features**

# %%
fig2 = plt.figure(figsize=(20,15))
ax1 = fig2.add_subplot(331)
ax1.set_title("track_album_name")
spotify_songs_df['track_album_name'].value_counts().head(10).plot(kind='barh')


ax1 = fig2.add_subplot(332)
ax1.set_title("track_name")
spotify_songs_df['track_name'].value_counts().head(10).plot(kind='barh')


ax1 = fig2.add_subplot(333)
ax1.set_title("track_artist")
spotify_songs_df['track_artist'].value_counts().head(10).plot(kind='barh')


ax1 = fig2.add_subplot(334)
ax1.set_title("track_album_release_date")
spotify_songs_df['track_album_release_date'].value_counts().head(10).plot(kind='barh')


ax1 = fig2.add_subplot(335)
ax1.set_title("playlist_subgenre")
spotify_songs_df['playlist_subgenre'].value_counts().head(10).plot(kind='barh')


ax1 = fig2.add_subplot(336)
ax1.set_title("playlist_genre")
spotify_songs_df['playlist_genre'].value_counts().head(10).plot(kind='barh')

ax1 = fig2.add_subplot(337)
ax1.set_title("playlist_name")
spotify_songs_df['playlist_name'].value_counts().head(10).plot(kind='barh')

plt.tight_layout()

# %% [markdown]
# **Heatmap**

# %%
df_corr = spotify_songs_df.drop(columns=['duration_ms', 'duration_s'])

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(df_corr.corr(), annot_kws={'weight':'bold'},linewidths=.5, cmap="Greens", annot=True)
plt.savefig("heatmap.png")

# %% [markdown]
# **Just histplots again with other visuals**

# %%
sns.set_theme()
fig, axes = plt.subplots(4, 3, figsize=(18, 10),dpi=200)
plt.subplots_adjust(hspace = 0.5)
plt.subplots_adjust(wspace = 0.25)

sns.histplot(ax=axes[0,0],data=spotify_songs_df,x='track_popularity',kde=False,bins=25,color='g',edgecolor='g',stat='density')
sns.kdeplot(data=spotify_songs_df, x="track_popularity", color='black', ax=axes[0][0], clip=(0,100))

sns.histplot(ax=axes[0,1],data=spotify_songs_df,x='danceability',kde=False,bins=25,color='g',edgecolor='g',stat='density')
sns.kdeplot(data=spotify_songs_df, x="danceability", color='black', ax=axes[0][1], clip=(0,1))

sns.histplot(ax=axes[0,2],data=spotify_songs_df,x='energy',kde=False,bins=25,color='g',edgecolor='g',stat='density')
sns.kdeplot(data=spotify_songs_df, x="energy", color='black', ax=axes[0][2], clip=(0,1))

sns.histplot(ax=axes[1,0],data=spotify_songs_df,x='loudness',kde=False,bins=50,color='g',edgecolor='g',stat='density')
sns.kdeplot(data=spotify_songs_df, x="loudness", color='black', ax=axes[1][0], clip=(-46.5,1.3))

sns.histplot(ax=axes[1,1],data=spotify_songs_df,x='speechiness',kde=False,bins=25,color='g',edgecolor='g',stat='density')
sns.kdeplot(data=spotify_songs_df, x="speechiness", color='black', ax=axes[1][1], clip=(0,1))

sns.histplot(ax=axes[1,2],data=spotify_songs_df,x='acousticness',kde=False,bins=25,color='g',edgecolor='g',stat='density')
sns.kdeplot(data=spotify_songs_df, x="acousticness", color='black', ax=axes[1][2], clip=(0,1))

sns.histplot(ax=axes[2,0],data=spotify_songs_df,x='instrumentalness',kde=False,bins=10,color='g',edgecolor='g',stat='density')
sns.kdeplot(data=spotify_songs_df, x="instrumentalness", color='black', ax=axes[2][0], clip=(0,1))

sns.histplot(ax=axes[2,1],data=spotify_songs_df,x='liveness',kde=False,bins=25,color='g',edgecolor='g',stat='density')
sns.kdeplot(data=spotify_songs_df, x="liveness", color='black', ax=axes[2][1], clip=(0,1))

sns.histplot(ax=axes[2,2],data=spotify_songs_df,x='valence',kde=False,bins=25,color='g',edgecolor='g',stat='density')
sns.kdeplot(data=spotify_songs_df, x="valence", color='black', ax=axes[2][2], clip=(0,1),bw_method=0.2)

sns.histplot(ax=axes[3,0],data=spotify_songs_df,x='tempo',kde=False,bins=25,color='g',edgecolor='g',stat='density')
sns.kdeplot(data=spotify_songs_df, x="tempo", color='black', ax=axes[3][0], bw_method=0.2)

sns.histplot(ax=axes[3,1],data=spotify_songs_df,x='duration_s',kde=False,bins=25,color='g',edgecolor='g',stat='density')
sns.kdeplot(data=spotify_songs_df, x="duration_s", color='black', ax=axes[3][1])

fig.delaxes(axes[3,2])

# %%
bp = sns.barplot(data=spotify_songs_df, x="track_popularity", y="playlist_genre", estimator=np.mean)
bp.set(title='Playlist Genre vs Avg Track Popularity')
bp.set_xlabel("Average Track Popularity", fontsize = 12)
bp.set_ylabel("Playlist Genre", fontsize = 12)
# Out:
# Text(0, 0.5, 'Playlist Genre')

# %%
plt.figure(figsize=(20,10))
spotify_songs_df[['track_popularity','playlist_subgenre']].groupby(['playlist_subgenre']).mean().plot.barh()
plt.title("Track Popularity vs Playlist Sub Genre",fontsize=15)
plt.show()
